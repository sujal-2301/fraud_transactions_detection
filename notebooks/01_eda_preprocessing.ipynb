# %% [markdown]
# # 01_EDA & Preprocessing
#
# This notebook will:
#
# 1. Load our credit-card transactions dataset
# 2. Inspect its shape, types and missing values
# 3. Explore basic statistics and distributions
# 4. Prepare it for modeling (drop unneeded columns, encode categoricals later)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# display plots inline
# %matplotlib inline

# %%
# adjust path if needed
df = pd.read_csv("../data/credit_card_transactions.csv")

# drop the auto-index column if present
if "Unnamed: 0" in df.columns:
    df.drop("Unnamed: 0", axis=1, inplace=True)

print("Loaded DataFrame with shape:", df.shape)
# Out:
# Loaded DataFrame with shape: (1296675, 23)

# %%
df.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
# 3  gas_transport   45.00     Jeremy    White      M
# 4       misc_pos   41.96      Tyler   Garcia      M
#
#                          street            city  ...      long  city_pop  \
# 0                561 Perry Cove  Moravian Falls  ...  -81.1781      3495
# ...

# %%
# data types & non-null counts
df.info()

# count of missing values per column
print("\nMissing values:\n", df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   trans_date_trans_time  1296675 non-null  object
#  1   cc_num                 1296675 non-null  int64
#  2   merchant               1296675 non-null  object
#  3   category               1296675 non-null  object
#  4   amt                    1296675 non-null  float64
#  5   first                  1296675 non-null  object
#  6   last                   1296675 non-null  object
#  7   gender                 1296675 non-null  object
#  8   street                 1296675 non-null  object
#  9   city                   1296675 non-null  object
#  10  state                  1296675 non-null  object
#  11  zip                    1296675 non-null  int64
#  12  lat                    1296675 non-null  float64
#  13  long                   1296675 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                    count          mean           std           min  \
# cc_num         1296675.0  4.171920e+17  1.308806e+18  6.041621e+10
# amt            1296675.0  7.035104e+01  1.603160e+02  1.000000e+00
# zip            1296675.0  4.880067e+04  2.689322e+04  1.257000e+03
# lat            1296675.0  3.853762e+01  5.075808e+00  2.002710e+01
# long           1296675.0 -9.022634e+01  1.375908e+01 -1.656723e+02
# city_pop       1296675.0  8.882444e+04  3.019564e+05  2.300000e+01
# unix_time      1296675.0  1.349244e+09  1.284128e+07  1.325376e+09
# merch_lat      1296675.0  3.853734e+01  5.109788e+00  1.902779e+01
# merch_long     1296675.0 -9.022646e+01  1.377109e+01 -1.666712e+02
# is_fraud       1296675.0  5.788652e-03  7.586269e-02  0.000000e+00
# merch_zipcode  1100702.0  4.682575e+04  2.583400e+04  1.001000e+03
#
#                         25%           50%           75%           max
# cc_num         1.800429e+14  3.521417e+15  4.642255e+15  4.992346e+18
# ...

# %%
for col in ["merchant", "category", "gender", "state", "is_fraud"]:
    print(f"{col:10s} → unique values: {df[col].nunique()}")
# Out:
# merchant   → unique values: 693
# category   → unique values: 14
# gender     → unique values: 2
# state      → unique values: 51
# is_fraud   → unique values: 2

# %%
counts = df["is_fraud"].value_counts()
print(counts)

# bar chart
counts.plot(kind="bar")
plt.title("Fraud vs. Legitimate Transactions")
plt.xlabel("is_fraud")
plt.ylabel("Count")
plt.show()
# Out:
# is_fraud
# 0    1289169
# 1       7506
# Name: count, dtype: int64

# %%
plt.hist(df["amt"], bins=50)
plt.title("Transaction Amount Distribution")
plt.xlabel("Amount")
plt.ylabel("Frequency")
plt.show()
